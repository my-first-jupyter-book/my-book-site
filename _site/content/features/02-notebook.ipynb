# %% [markdown]
# # Notebook 2

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Some plot

# %%
ts = pd.Series(np.random.randn(1000),
                index=pd.date_range('1/1/2000', periods=1000))


ts = ts.cumsum()

ts.plot()

# %% [markdown]
# ## Some conclusions

# %% [markdown]
# - Many great conclusions
